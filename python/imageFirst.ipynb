# %%
import skimage as sk
import matplotlib.pyplot as plt

# %%
coins = sk.data.coins()

# %%
coins.shape
# Out:
# (303, 384)

# %%
sk.io.imshow(coins)

# %%
coin_edit = coins[0:100, 0:150]

# %%
coin_edit
# Out:
# array([[ 47, 123, 133, ..., 125, 128, 130],
#        [ 93, 144, 145, ..., 126, 128, 129],
#        [126, 147, 143, ..., 124, 126, 127],
#        ...,
#        [103, 102, 101, ...,  65,  67,  69],
#        [102, 103, 103, ...,  66,  65,  65],
#        [ 99, 101, 102, ...,  67,  64,  64]], dtype=uint8)

# %%
sk.io.imshow(coin_edit)

# %%
astro = sk.data.astronaut()

# %%
sk.io.imshow(astro)

# %%
astro_trimed = astro[0:200, 150:300]

# %%
sk.io.imshow(astro_trimed)

# %%
astro_trimed[:, :, 1] = 0
astro_trimed[:, :, 2] = 0

# %%
red
# Out:
# 0

# %%
sk.io.imshow(astro)

# %%
red_new = astro.copy()
