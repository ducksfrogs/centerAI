# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(-100, 100)

# %%
y = x

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
y = x**2

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
y = x**3

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
