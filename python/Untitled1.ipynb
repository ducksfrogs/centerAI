# %%
import skimage as sk

# %%
coins = sk.data.coins()

# %%
coins.shape
# Out:
# (303, 384)

# %%
sk.io.imshow(coins)

# %%
coins
# Out:
# array([[ 47, 123, 133, ...,  14,   3,  12],
#        [ 93, 144, 145, ...,  12,   7,   7],
#        [126, 147, 143, ...,   2,  13,   3],
#        ...,
#        [ 81,  79,  74, ...,   6,   4,   7],
#        [ 88,  82,  74, ...,   5,   7,   8],
#        [ 91,  79,  68, ...,   4,  10,   7]], dtype=uint8)
